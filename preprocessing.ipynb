# %%
import pandas as pd

# %%
data=pd.read_csv("https://raw.githubusercontent.com/Laxminarayen/Inceptez-DS-Batch20/main/12.%20Preprocessing/Demand_txn_updated.csv")

# %%
data.head(15)
# Out:
#          City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0   Hyderabad         Take Away              9978        7/31/2018
# 1   Hyderabad         Take Away              4064        7/31/2018
# 2   Hyderabad         Main Hall               965        7/31/2018
# 3   Hyderabad           Express              9978        7/31/2018
# 4   Hyderabad           Express              1045        7/31/2018
# 5   Hyderabad          Delivery              4056        7/31/2018
# 6   Hyderabad         Take Away              4065        7/31/2018
# 7   Hyderabad           Express              4058        7/31/2018
# 8   Hyderabad           Express              4057        7/31/2018
# 9   Hyderabad           Express              4056        7/31/2018
# 10  Hyderabad          Delivery              4061        7/31/2018
# 11  Hyderabad           Express              4055        7/31/2018
# 12  Hyderabad         Take Away              4061        7/31/2018
# ...

# %%
data.dtypes
# Out:
# City                                           object
# Mapped_Sales_Type                              object
# Mapped_Item_Code                                int64
# Transaction_Date                               object
# Quantity_Sold                                   int64
# Median_Price                                  float64
# Average_Tax_Percent                           float64
# Effective_Price                               float64
# Percent_Quantity_With_Discount                float64
# Avg_Discount_Percent_On_Discounted_Items      float64
# Year                                            int64
# Month                                           int64
# Day                                            object
# Car_sales                                     float64
# F_and_B_Inflation                             float64
# F_and_B_Inflation_Adjusted_Effective_Price    float64
# F_and_B_Inflation_Adjusted_Median_Price       float64
# ...

# %%
data['Transaction_Date']=pd.to_datetime(data['Transaction_Date'])

# %%
data.head(5)
# Out:
#         City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0  Hyderabad         Take Away              9978       2018-07-31
# 1  Hyderabad         Take Away              4064       2018-07-31
# 2  Hyderabad         Main Hall               965       2018-07-31
# 3  Hyderabad           Express              9978       2018-07-31
# 4  Hyderabad           Express              1045       2018-07-31
#
#    Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 0            167         187.0                 0.05       163.700000
# 1            368         602.0                 0.05       584.329105
# 2            694         263.0                 0.05       244.835163
# 3            140         263.0                 0.05       243.500000
# 4            139         392.0                 0.05       378.960000
#
#    Percent_Quantity_With_Discount  Avg_Discount_Percent_On_Discounted_Items  \
# ...

# %%
data_sub = data[data['Transaction_Date']>'2016-08-01']

# %%
data_sub
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978       2018-07-31
# 1      Hyderabad         Take Away              4064       2018-07-31
# 2      Hyderabad         Main Hall               965       2018-07-31
# 3      Hyderabad           Express              9978       2018-07-31
# 4      Hyderabad           Express              1045       2018-07-31
# ...          ...               ...               ...              ...
# 30187     Mumbai         Take Away              4059       2016-08-02
# 30188     Mumbai         Main Hall               966       2016-08-02
# 30189     Mumbai         Take Away              4065       2016-08-02
# 30190     Mumbai          Delivery              4057       2016-08-02
# 30191     Mumbai         Take Away              4061       2016-08-02
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %%
data['Mapped_Sales_Type'].unique()
# Out:
# array(['Take Away', 'Main Hall', 'Express', 'Delivery', 'Dine-in',
#        'Bakery'], dtype=object)

# %%
data1=data[data['Avg_Discount_Percent_On_Discounted_Items']< 0.1]

# %%
data1['Avg_Discount_Percent_On_Discounted_Items'].unique()
# Out:
# array([0.0583341 , 0.05250228, 0.09450976, 0.08750194, 0.0958697 ,
#        0.0787405 , 0.05249125, 0.05250137, 0.05999919, 0.0918725 ,
#        0.05250033, 0.08749844, 0.04991194, 0.04991194, 0.05249857,
#        0.05277491, 0.05500064, 0.05250069, 0.05249764, 0.07875255,
#        0.05395821, 0.07874951, 0.05250962, 0.05250022, 0.07495882,
#        0.06871908, 0.06999156, 0.08530723, 0.05250048, 0.04938887,
#        0.0451887 , 0.07515143, 0.09708106, 0.05526478, 0.06416671,
#        0.05249968, 0.06562511, 0.07      , 0.09450935, 0.05249853,
#        0.08849951, 0.059     , 0.05900901, 0.06000957, 0.07080374,
#        0.07063218, 0.05899642, 0.0590016 , 0.05899966, 0.08850467,
#        0.082     , 0.06773542, 0.0885044 , 0.05900074, 0.09833333,
#        0.0572496 , 0.05724953, 0.0602551 , 0.05935418, 0.0572484 ,
#        0.05725221, 0.0964    , 0.07230108, 0.05725333, 0.0602517 ,
#        0.05725   , 0.07410714, 0.08033236, 0.06023365, 0.06025   ,
# ...

# %%
data1[data1['Avg_Discount_Percent_On_Discounted_Items']>=0.1]
# Out:
# Empty DataFrame
# Columns: [City, Mapped_Sales_Type, Mapped_Item_Code, Transaction_Date, Quantity_Sold, Median_Price, Average_Tax_Percent, Effective_Price, Percent_Quantity_With_Discount, Avg_Discount_Percent_On_Discounted_Items, Year, Month, Day, Car_sales, F_and_B_Inflation, F_and_B_Inflation_Adjusted_Effective_Price, F_and_B_Inflation_Adjusted_Median_Price, First_Week_Of_The_Month_Dummy, Last_Week_Of_The_Month_Dummy, Day_Of_The_Week_Seasonality, Month_Of_The_Year_Seasonality, Two_Wheeler_sales, Date]
# Index: []
#
# [0 rows x 23 columns]

# %%
data_cpy['Avg_Discount_Percent_On_Discounted_Items']=data_cpy['Avg_Discount_Percent_On_Discounted_Items']<0.1

# %%
data.columns
# Out:
# Index(['City', 'Mapped_Sales_Type', 'Mapped_Item_Code', 'Transaction_Date',
#        'Quantity_Sold', 'Median_Price', 'Average_Tax_Percent',
#        'Effective_Price', 'Percent_Quantity_With_Discount',
#        'Avg_Discount_Percent_On_Discounted_Items', 'Year', 'Month', 'Day',
#        'Car_sales', 'F_and_B_Inflation',
#        'F_and_B_Inflation_Adjusted_Effective_Price',
#        'F_and_B_Inflation_Adjusted_Median_Price',
#        'First_Week_Of_The_Month_Dummy', 'Last_Week_Of_The_Month_Dummy',
#        'Day_Of_The_Week_Seasonality', 'Month_Of_The_Year_Seasonality',
#        'Two_Wheeler_sales', 'Date'],
#       dtype='object')

# %%
data_quan=data.groupby(['City', 'Mapped_Sales_Type', 'Mapped_Item_Code', 'Transaction_Date'])['Quantity_Sold'].aggregate('sum')

# %%
data_quan
# Out:
# City     Mapped_Sales_Type  Mapped_Item_Code  Transaction_Date
# Chennai  Bakery             4057              2017-08-05          110
#                             9978              2018-01-22          105
#          Delivery           4055              2017-08-04          377
#                                               2017-08-05          377
#                                               2017-08-06          638
#                                                                  ...
# Mumbai   Take Away          4068              2017-01-09          200
#                                               2017-01-10          199
#                                               2017-01-11          239
#                                               2017-01-12          233
#                                               2017-01-13          273
# Name: Quantity_Sold, Length: 30231, dtype: int64

# %%
data_median=data.groupby(['City', 'Mapped_Sales_Type', 'Mapped_Item_Code', 'Transaction_Date'])['Median_Price'].aggregate('median')

# %%
data_median
# Out:
# City     Mapped_Sales_Type  Mapped_Item_Code  Transaction_Date
# Chennai  Bakery             4057              2017-08-05          223.0
#                             9978              2018-01-22          178.0
#          Delivery           4055              2017-08-04          260.0
#                                               2017-08-05          260.0
#                                               2017-08-06          260.0
#                                                                   ...
# Mumbai   Take Away          4068              2017-01-09          405.0
#                                               2017-01-10          405.0
#                                               2017-01-11          405.0
#                                               2017-01-12          405.0
#                                               2017-01-13          405.0
# Name: Median_Price, Length: 30231, dtype: float64

# %%
data_eff=data.groupby(['City', 'Mapped_Sales_Type', 'Mapped_Item_Code', 'Transaction_Date'])['Effective_Price'].aggregate('median')

# %%
data_eff
# Out:
# City     Mapped_Sales_Type  Mapped_Item_Code  Transaction_Date
# Chennai  Bakery             4057              2017-08-05          221.000000
#                             9978              2018-01-22          154.250000
#          Delivery           4055              2017-08-04          264.113759
#                                               2017-08-05          264.138571
#                                               2017-08-06          264.223814
#                                                                      ...
# Mumbai   Take Away          4068              2017-01-09          424.140000
#                                               2017-01-10          424.140000
#                                               2017-01-11          424.140000
#                                               2017-01-12          424.140000
#                                               2017-01-13          423.201358
# Name: Effective_Price, Length: 30231, dtype: float64

# %%
data.groupby(['City', 'Mapped_Sales_Type', 'Mapped_Item_Code', 'Transaction_Date']).aggregate({'Quantity_Sold':'sum',
                                                                                                          'Median_Price' : 'median',
                                                                                                          'Effective_Price' : 'median'})
# Out:
#                                                              Quantity_Sold  \
# City    Mapped_Sales_Type Mapped_Item_Code Transaction_Date
# Chennai Bakery            4057             2017-08-05                  110
#                           9978             2018-01-22                  105
#         Delivery          4055             2017-08-04                  377
#                                            2017-08-05                  377
#                                            2017-08-06                  638
# ...                                                                    ...
# Mumbai  Take Away         4068             2017-01-09                  200
#                                            2017-01-10                  199
#                                            2017-01-11                  239
#                                            2017-01-12                  233
#                                            2017-01-13                  273
#
# ...

# %%
data[data['Effective_Price'].notnull()]
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978       2018-07-31
# 1      Hyderabad         Take Away              4064       2018-07-31
# 2      Hyderabad         Main Hall               965       2018-07-31
# 3      Hyderabad           Express              9978       2018-07-31
# 4      Hyderabad           Express              1045       2018-07-31
# ...          ...               ...               ...              ...
# 30226     Mumbai         Take Away              4056       2016-08-01
# 30227     Mumbai         Take Away              4058       2016-08-01
# 30228     Mumbai           Dine-in               964       2016-08-01
# 30229     Mumbai         Take Away              4066       2016-08-01
# 30230     Mumbai          Delivery              4061       2016-08-01
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %%
data[data['Effective_Price'].isnull()]
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 1994   Hyderabad           Express              4057       2018-06-20
# 16517    Chennai          Delivery              4062       2017-08-07
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 1994             111        312.00                 0.05              NaN
# 16517            111        819.61                 0.18              NaN
#
#        Percent_Quantity_With_Discount  \
# 1994                              NaN
# 16517                             NaN
#
#        Avg_Discount_Percent_On_Discounted_Items  ...  Car_sales  \
# 1994                                        NaN  ...    7559.28
# 16517                                       NaN  ...    8258.88
#
#        F_and_B_Inflation F_and_B_Inflation_Adjusted_Effective_Price  \
# 1994               141.4                                        NaN
# 16517              143.8                                        NaN
#
# ...

# %%
data[data['Effective_Price'].notnull()].tail(5)
# Out:
#          City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 30226  Mumbai         Take Away              4056       2016-08-01
# 30227  Mumbai         Take Away              4058       2016-08-01
# 30228  Mumbai           Dine-in               964       2016-08-01
# 30229  Mumbai         Take Away              4066       2016-08-01
# 30230  Mumbai          Delivery              4061       2016-08-01
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 30226            615         239.0                 0.14       232.033552
# 30227           1289         212.8                 0.14       202.575840
# 30228            140         933.0                 0.21      1063.855517
# 30229            179         501.0                 0.14       534.060000
# 30230            117         716.5                 0.15       780.810000
#
#        Percent_Quantity_With_Discount  \
# 30226                        0.013889
# 30227                        0.009338
# ...

# %%
data[(data['City']=='Chennai') & (data['Mapped_Sales_Type']=='Delivery')]
# Out:
#           City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 8379   Chennai          Delivery              4055       2018-02-05
# 8384   Chennai          Delivery              4068       2018-02-05
# 8387   Chennai          Delivery              4064       2018-02-05
# 8388   Chennai          Delivery              4058       2018-02-05
# 8392   Chennai          Delivery              4061       2018-02-05
# ...        ...               ...               ...              ...
# 16606  Chennai          Delivery              4057       2017-08-04
# 16609  Chennai          Delivery              4056       2017-08-04
# 16611  Chennai          Delivery              4059       2017-08-04
# 16612  Chennai          Delivery              4063       2017-08-04
# 16614  Chennai          Delivery              4066       2017-08-04
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 8379             544        281.10                 0.05       262.502194
# ...

# %%
data.loc[(data['City']=='Chennai') & (data['Mapped_Sales_Type']=='Delivery')]
# Out:
#           City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 8379   Chennai          Delivery              4055       2018-02-05
# 8384   Chennai          Delivery              4068       2018-02-05
# 8387   Chennai          Delivery              4064       2018-02-05
# 8388   Chennai          Delivery              4058       2018-02-05
# 8392   Chennai          Delivery              4061       2018-02-05
# ...        ...               ...               ...              ...
# 16606  Chennai          Delivery              4057       2017-08-04
# 16609  Chennai          Delivery              4056       2017-08-04
# 16611  Chennai          Delivery              4059       2017-08-04
# 16612  Chennai          Delivery              4063       2017-08-04
# 16614  Chennai          Delivery              4066       2017-08-04
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 8379             544        281.10                 0.05       262.502194
# ...

# %%
data[data['Day'].isin(['Mon','Tue','Wed'])]
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978       2018-07-31
# 1      Hyderabad         Take Away              4064       2018-07-31
# 2      Hyderabad         Main Hall               965       2018-07-31
# 3      Hyderabad           Express              9978       2018-07-31
# 4      Hyderabad           Express              1045       2018-07-31
# ...          ...               ...               ...              ...
# 30226     Mumbai         Take Away              4056       2016-08-01
# 30227     Mumbai         Take Away              4058       2016-08-01
# 30228     Mumbai           Dine-in               964       2016-08-01
# 30229     Mumbai         Take Away              4066       2016-08-01
# 30230     Mumbai          Delivery              4061       2016-08-01
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %%
data[data['Percent_Quantity_With_Discount'] != 0.0]
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978       2018-07-31
# 1      Hyderabad         Take Away              4064       2018-07-31
# 2      Hyderabad         Main Hall               965       2018-07-31
# 3      Hyderabad           Express              9978       2018-07-31
# 4      Hyderabad           Express              1045       2018-07-31
# ...          ...               ...               ...              ...
# 30226     Mumbai         Take Away              4056       2016-08-01
# 30227     Mumbai         Take Away              4058       2016-08-01
# 30228     Mumbai           Dine-in               964       2016-08-01
# 30229     Mumbai         Take Away              4066       2016-08-01
# 30230     Mumbai          Delivery              4061       2016-08-01
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %%
data['t1'] = data['Effective_Price'].apply(lambda x : 1 if x>500 else 0.5 )

# %%
data['t1']
# Out:
# 0        0.5
# 1        1.0
# 2        0.5
# 3        0.5
# 4        0.5
#         ...
# 30226    0.5
# 30227    0.5
# 30228    1.0
# 30229    1.0
# 30230    1.0
# Name: t1, Length: 30231, dtype: float64
